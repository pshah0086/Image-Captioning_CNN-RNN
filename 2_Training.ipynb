# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** In this project I used the ResNet-152 pre-trained model for CNN-Encoder, which among those available from PyTorch : https://pytorch.org/docs/master/torchvision/models.html , is the one that is performing best on the ImageNet dataset.
# The RNN-Decoder consists in a LSTM followed by a hidden layer, this architecture was presented from the paper Show and Tell: A Neural Image Caption Generator (2014) https://arxiv.org/pdf/1411.4555.pdf (figure 4)
#
# Hyperparameters:
#
# batch_size = 32`: To speed up the computations and reducing the variance
# `vocab_threshold = 6`: With a vocabulary threshold of 6, the total number of tokens in the vocabulary is 9985, which is acceptable.
# `embed_size = 512` and `hidden_size = 512`: From `Show and tell`, section **4.3.1 Training Details**
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** The input of the CNN-encoder accepts an image of size (224 x 224 x 3), hence this is the final size of the image we are aiming for. Before doing that, we can augment our training data by randomly cropping an area of the image after resizing the image to 256. We also use a horizontal flip to augment our data with a probability of 0.5 and then convert the image to a Tensor. Finally we normalize the image by the values used for the ImageNet-dataset so that we are consistent with the pre-trained model.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** For CNN-Encoder we are using Pre-trained network nad only change that we made to it is in it's last FC layer, so we only have to train that in case of CNN.
# Whereas in case of RNN-Decoder we are training it from scratch so we take in all the parameters.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** I used Adam Optimizer as it is considered to be giving best results since we keep track of the previous gradient to not end up in a local minima.

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.6/site-packages (3.2.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from nltk) (1.11.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 6        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 2             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.98s)
# creating index...
#   0%|          | 782/414113 [00:00<01:50, 3724.65it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:36<00:00, 4303.93it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/2], Step [100/12942], Loss: 3.7006, Perplexity: 40.4704
# Epoch [1/2], Step [200/12942], Loss: 3.4680, Perplexity: 32.07254
# Epoch [1/2], Step [300/12942], Loss: 3.1410, Perplexity: 23.1280
# Epoch [1/2], Step [400/12942], Loss: 3.6015, Perplexity: 36.6517
# Epoch [1/2], Step [500/12942], Loss: 3.0341, Perplexity: 20.7821
# Epoch [1/2], Step [600/12942], Loss: 2.9840, Perplexity: 19.7666
# Epoch [1/2], Step [700/12942], Loss: 3.2686, Perplexity: 26.2750
# Epoch [1/2], Step [800/12942], Loss: 2.6505, Perplexity: 14.1614
# Epoch [1/2], Step [900/12942], Loss: 3.0031, Perplexity: 20.1487
# Epoch [1/2], Step [1000/12942], Loss: 2.9288, Perplexity: 18.7056
# Epoch [1/2], Step [1100/12942], Loss: 2.7728, Perplexity: 16.0032
# Epoch [1/2], Step [1200/12942], Loss: 2.7098, Perplexity: 15.0270
# Epoch [1/2], Step [1300/12942], Loss: 2.8398, Perplexity: 17.1116
# Epoch [1/2], Step [1400/12942], Loss: 3.4908, Perplexity: 32.8113
# Epoch [1/2], Step [1500/12942], Loss: 2.7826, Perplexity: 16.1609
# Epoch [1/2], Step [1600/12942], Loss: 2.5786, Perplexity: 13.17853
# Epoch [1/2], Step [1700/12942], Loss: 2.4130, Perplexity: 11.1676
# Epoch [1/2], Step [1800/12942], Loss: 2.3716, Perplexity: 10.7143
# Epoch [1/2], Step [1900/12942], Loss: 2.8027, Perplexity: 16.4886
# Epoch [1/2], Step [2000/12942], Loss: 2.7932, Perplexity: 16.3336
# Epoch [1/2], Step [2100/12942], Loss: 2.5484, Perplexity: 12.7869
# Epoch [1/2], Step [2200/12942], Loss: 2.2017, Perplexity: 9.04061
# Epoch [1/2], Step [2300/12942], Loss: 2.4909, Perplexity: 12.0716
# Epoch [1/2], Step [2400/12942], Loss: 2.4316, Perplexity: 11.3770
# Epoch [1/2], Step [2500/12942], Loss: 2.9208, Perplexity: 18.5558
# Epoch [1/2], Step [2600/12942], Loss: 2.7609, Perplexity: 15.8148
# Epoch [1/2], Step [2700/12942], Loss: 2.8774, Perplexity: 17.7674
# Epoch [1/2], Step [2800/12942], Loss: 2.5406, Perplexity: 12.6874
# Epoch [1/2], Step [2900/12942], Loss: 2.7155, Perplexity: 15.1125
# Epoch [1/2], Step [3000/12942], Loss: 2.2028, Perplexity: 9.05067
# Epoch [1/2], Step [3100/12942], Loss: 2.5153, Perplexity: 12.3698
# Epoch [1/2], Step [3200/12942], Loss: 2.4758, Perplexity: 11.8911
# Epoch [1/2], Step [3300/12942], Loss: 2.7478, Perplexity: 15.6083
# Epoch [1/2], Step [3400/12942], Loss: 2.4368, Perplexity: 11.4360
# Epoch [1/2], Step [3500/12942], Loss: 2.5961, Perplexity: 13.4111
# Epoch [1/2], Step [3600/12942], Loss: 2.1206, Perplexity: 8.33646
# Epoch [1/2], Step [3700/12942], Loss: 2.6888, Perplexity: 14.7142
# Epoch [1/2], Step [3800/12942], Loss: 2.2134, Perplexity: 9.146922
# Epoch [1/2], Step [3900/12942], Loss: 2.1517, Perplexity: 8.59956
# Epoch [1/2], Step [4000/12942], Loss: 2.3812, Perplexity: 10.8182
# Epoch [1/2], Step [4100/12942], Loss: 2.2407, Perplexity: 9.40010
# Epoch [1/2], Step [4200/12942], Loss: 2.2208, Perplexity: 9.21498
# Epoch [1/2], Step [4300/12942], Loss: 2.6781, Perplexity: 14.5569
# Epoch [1/2], Step [4400/12942], Loss: 2.2149, Perplexity: 9.16012
# Epoch [1/2], Step [4500/12942], Loss: 2.5132, Perplexity: 12.3443
# Epoch [1/2], Step [4600/12942], Loss: 2.3257, Perplexity: 10.2339
# Epoch [1/2], Step [4700/12942], Loss: 2.3830, Perplexity: 10.8372
# Epoch [1/2], Step [4800/12942], Loss: 2.3870, Perplexity: 10.8805
# Epoch [1/2], Step [4900/12942], Loss: 2.5583, Perplexity: 12.9141
# Epoch [1/2], Step [5000/12942], Loss: 2.1086, Perplexity: 8.23682
# Epoch [1/2], Step [5100/12942], Loss: 2.2028, Perplexity: 9.05010
# Epoch [1/2], Step [5200/12942], Loss: 2.4943, Perplexity: 12.1131
# Epoch [1/2], Step [5300/12942], Loss: 2.5597, Perplexity: 12.9323
# Epoch [1/2], Step [5400/12942], Loss: 2.6080, Perplexity: 13.5718
# Epoch [1/2], Step [5500/12942], Loss: 2.1957, Perplexity: 8.98603
# Epoch [1/2], Step [5600/12942], Loss: 2.2997, Perplexity: 9.97125
# Epoch [1/2], Step [5700/12942], Loss: 2.4776, Perplexity: 11.9131
# Epoch [1/2], Step [5800/12942], Loss: 2.2543, Perplexity: 9.52825
# Epoch [1/2], Step [5900/12942], Loss: 2.3133, Perplexity: 10.1078
# Epoch [1/2], Step [6000/12942], Loss: 2.0522, Perplexity: 7.78494
# Epoch [1/2], Step [6100/12942], Loss: 2.3854, Perplexity: 10.8638
# Epoch [1/2], Step [6200/12942], Loss: 2.4246, Perplexity: 11.2979
# Epoch [1/2], Step [6300/12942], Loss: 2.2366, Perplexity: 9.36189
# Epoch [1/2], Step [6400/12942], Loss: 2.2339, Perplexity: 9.33571
# Epoch [1/2], Step [6500/12942], Loss: 2.3738, Perplexity: 10.7379
# Epoch [1/2], Step [6600/12942], Loss: 2.3053, Perplexity: 10.0274
# Epoch [1/2], Step [6700/12942], Loss: 2.6839, Perplexity: 14.6419
# Epoch [1/2], Step [6800/12942], Loss: 2.0951, Perplexity: 8.12676
# Epoch [1/2], Step [6900/12942], Loss: 2.4055, Perplexity: 11.0841
# Epoch [1/2], Step [7000/12942], Loss: 2.2702, Perplexity: 9.68121
# Epoch [1/2], Step [7100/12942], Loss: 2.2293, Perplexity: 9.29344
# Epoch [1/2], Step [7200/12942], Loss: 2.4551, Perplexity: 11.6480
# Epoch [1/2], Step [7300/12942], Loss: 2.4024, Perplexity: 11.0500
# Epoch [1/2], Step [7400/12942], Loss: 2.1096, Perplexity: 8.24467
# Epoch [1/2], Step [7500/12942], Loss: 2.6546, Perplexity: 14.2193
# Epoch [1/2], Step [7600/12942], Loss: 2.1908, Perplexity: 8.94226
# Epoch [1/2], Step [7700/12942], Loss: 2.3674, Perplexity: 10.6696
# Epoch [1/2], Step [7800/12942], Loss: 2.5371, Perplexity: 12.6432
# Epoch [1/2], Step [7900/12942], Loss: 2.2114, Perplexity: 9.12878
# Epoch [1/2], Step [8000/12942], Loss: 2.2251, Perplexity: 9.25461
# Epoch [1/2], Step [8100/12942], Loss: 2.2943, Perplexity: 9.91707
# Epoch [1/2], Step [8200/12942], Loss: 2.1149, Perplexity: 8.28897
# Epoch [1/2], Step [8300/12942], Loss: 2.2508, Perplexity: 9.49544
# Epoch [1/2], Step [8400/12942], Loss: 2.5660, Perplexity: 13.0134
# Epoch [1/2], Step [8500/12942], Loss: 2.2315, Perplexity: 9.31412
# Epoch [1/2], Step [8600/12942], Loss: 2.3752, Perplexity: 10.7527
# Epoch [1/2], Step [8700/12942], Loss: 2.0622, Perplexity: 7.86315
# Epoch [1/2], Step [8800/12942], Loss: 2.2509, Perplexity: 9.49643
# Epoch [1/2], Step [8900/12942], Loss: 2.0253, Perplexity: 7.57837
# Epoch [1/2], Step [9000/12942], Loss: 2.3586, Perplexity: 10.5764
# Epoch [1/2], Step [9100/12942], Loss: 2.0531, Perplexity: 7.79194
# Epoch [1/2], Step [9200/12942], Loss: 2.3244, Perplexity: 10.2202
# Epoch [1/2], Step [9300/12942], Loss: 2.5633, Perplexity: 12.9786
# Epoch [1/2], Step [9400/12942], Loss: 1.9569, Perplexity: 7.07715
# Epoch [1/2], Step [9500/12942], Loss: 2.2269, Perplexity: 9.27072
# Epoch [1/2], Step [9600/12942], Loss: 2.3408, Perplexity: 10.3895
# Epoch [1/2], Step [9700/12942], Loss: 2.1389, Perplexity: 8.49042
# Epoch [1/2], Step [9800/12942], Loss: 2.3328, Perplexity: 10.3071
# Epoch [1/2], Step [9900/12942], Loss: 2.2784, Perplexity: 9.76061
# Epoch [1/2], Step [10000/12942], Loss: 2.1941, Perplexity: 8.9722
# Epoch [1/2], Step [10100/12942], Loss: 2.3931, Perplexity: 10.9472
# Epoch [1/2], Step [10200/12942], Loss: 2.3290, Perplexity: 10.2672
# Epoch [1/2], Step [10300/12942], Loss: 2.8721, Perplexity: 17.6744
# Epoch [1/2], Step [10400/12942], Loss: 2.0868, Perplexity: 8.05904
# Epoch [1/2], Step [10500/12942], Loss: 1.9679, Perplexity: 7.15567
# Epoch [1/2], Step [10600/12942], Loss: 2.1344, Perplexity: 8.45187
# Epoch [1/2], Step [10700/12942], Loss: 2.2633, Perplexity: 9.61503
# Epoch [1/2], Step [10800/12942], Loss: 2.3615, Perplexity: 10.6073
# Epoch [1/2], Step [10900/12942], Loss: 2.1392, Perplexity: 8.49299
# Epoch [1/2], Step [11000/12942], Loss: 2.2520, Perplexity: 9.50700
# Epoch [1/2], Step [11100/12942], Loss: 2.0673, Perplexity: 7.90372
# Epoch [1/2], Step [11200/12942], Loss: 2.5797, Perplexity: 13.1928
# Epoch [1/2], Step [11300/12942], Loss: 2.1140, Perplexity: 8.28155
# Epoch [1/2], Step [11400/12942], Loss: 2.2035, Perplexity: 9.05648
# Epoch [1/2], Step [11500/12942], Loss: 1.9157, Perplexity: 6.79145
# Epoch [1/2], Step [11600/12942], Loss: 2.2522, Perplexity: 9.50919
# Epoch [1/2], Step [11700/12942], Loss: 2.3058, Perplexity: 10.0323
# Epoch [1/2], Step [11800/12942], Loss: 2.0683, Perplexity: 7.91131
# Epoch [1/2], Step [11900/12942], Loss: 2.1531, Perplexity: 8.61131
# Epoch [1/2], Step [12000/12942], Loss: 2.1070, Perplexity: 8.22334
# Epoch [1/2], Step [12100/12942], Loss: 2.2578, Perplexity: 9.56182
# Epoch [1/2], Step [12200/12942], Loss: 2.5820, Perplexity: 13.2242
# Epoch [1/2], Step [12300/12942], Loss: 2.2064, Perplexity: 9.08289
# Epoch [1/2], Step [12400/12942], Loss: 1.9960, Perplexity: 7.35926
# Epoch [1/2], Step [12500/12942], Loss: 1.9734, Perplexity: 7.19548
# Epoch [1/2], Step [12600/12942], Loss: 2.2333, Perplexity: 9.33098
# Epoch [1/2], Step [12700/12942], Loss: 1.8887, Perplexity: 6.61077
# Epoch [1/2], Step [12800/12942], Loss: 2.0642, Perplexity: 7.87928
# Epoch [1/2], Step [12900/12942], Loss: 2.3941, Perplexity: 10.9580
# Epoch [2/2], Step [100/12942], Loss: 2.2572, Perplexity: 9.5563634
# Epoch [2/2], Step [200/12942], Loss: 2.0866, Perplexity: 8.05773
# Epoch [2/2], Step [300/12942], Loss: 2.3822, Perplexity: 10.8290
# Epoch [2/2], Step [400/12942], Loss: 2.2320, Perplexity: 9.31856
# Epoch [2/2], Step [500/12942], Loss: 2.1108, Perplexity: 8.25495
# Epoch [2/2], Step [600/12942], Loss: 2.0792, Perplexity: 7.99845
# Epoch [2/2], Step [700/12942], Loss: 2.1800, Perplexity: 8.84595
# Epoch [2/2], Step [800/12942], Loss: 2.2653, Perplexity: 9.63364
# Epoch [2/2], Step [900/12942], Loss: 2.1294, Perplexity: 8.40970
# Epoch [2/2], Step [1000/12942], Loss: 2.3267, Perplexity: 10.2436
# Epoch [2/2], Step [1100/12942], Loss: 2.2087, Perplexity: 9.10364
# Epoch [2/2], Step [1200/12942], Loss: 2.0543, Perplexity: 7.80101
# Epoch [2/2], Step [1300/12942], Loss: 2.0823, Perplexity: 8.02301
# Epoch [2/2], Step [1400/12942], Loss: 2.1414, Perplexity: 8.51117
# Epoch [2/2], Step [1500/12942], Loss: 2.3130, Perplexity: 10.1048
# Epoch [2/2], Step [1600/12942], Loss: 2.1765, Perplexity: 8.81534
# Epoch [2/2], Step [1700/12942], Loss: 2.0865, Perplexity: 8.05637
# Epoch [2/2], Step [1800/12942], Loss: 2.2467, Perplexity: 9.45628
# Epoch [2/2], Step [1900/12942], Loss: 2.3683, Perplexity: 10.6791
# Epoch [2/2], Step [2000/12942], Loss: 2.0773, Perplexity: 7.98338
# Epoch [2/2], Step [2100/12942], Loss: 2.3292, Perplexity: 10.2696
# Epoch [2/2], Step [2200/12942], Loss: 2.9740, Perplexity: 19.5709
# Epoch [2/2], Step [2300/12942], Loss: 1.8739, Perplexity: 6.51388
# Epoch [2/2], Step [2400/12942], Loss: 2.1860, Perplexity: 8.89961
# Epoch [2/2], Step [2500/12942], Loss: 2.0377, Perplexity: 7.67266
# Epoch [2/2], Step [2600/12942], Loss: 2.1826, Perplexity: 8.86919
# Epoch [2/2], Step [2700/12942], Loss: 1.8801, Perplexity: 6.55414
# Epoch [2/2], Step [2800/12942], Loss: 2.3295, Perplexity: 10.2727
# Epoch [2/2], Step [2900/12942], Loss: 2.1550, Perplexity: 8.62791
# Epoch [2/2], Step [3000/12942], Loss: 2.1573, Perplexity: 8.64780
# Epoch [2/2], Step [3100/12942], Loss: 2.3316, Perplexity: 10.2940
# Epoch [2/2], Step [3200/12942], Loss: 2.1612, Perplexity: 8.68199
# Epoch [2/2], Step [3300/12942], Loss: 2.0755, Perplexity: 7.96849
# Epoch [2/2], Step [3400/12942], Loss: 2.1471, Perplexity: 8.56031
# Epoch [2/2], Step [3500/12942], Loss: 2.0585, Perplexity: 7.83422
# Epoch [2/2], Step [3600/12942], Loss: 2.2121, Perplexity: 9.13509
# Epoch [2/2], Step [3700/12942], Loss: 2.9674, Perplexity: 19.4422
# Epoch [2/2], Step [3800/12942], Loss: 2.6926, Perplexity: 14.7707
# Epoch [2/2], Step [3900/12942], Loss: 2.6630, Perplexity: 14.3392
# Epoch [2/2], Step [4000/12942], Loss: 2.3550, Perplexity: 10.5381
# Epoch [2/2], Step [4100/12942], Loss: 2.2280, Perplexity: 9.28179
# Epoch [2/2], Step [4200/12942], Loss: 2.0120, Perplexity: 7.47859
# Epoch [2/2], Step [4300/12942], Loss: 2.5229, Perplexity: 12.4651
# Epoch [2/2], Step [4400/12942], Loss: 1.9137, Perplexity: 6.77780
# Epoch [2/2], Step [4500/12942], Loss: 2.0069, Perplexity: 7.44046
# Epoch [2/2], Step [4600/12942], Loss: 2.5052, Perplexity: 12.2465
# Epoch [2/2], Step [4700/12942], Loss: 1.8940, Perplexity: 6.64588
# Epoch [2/2], Step [4800/12942], Loss: 2.1185, Perplexity: 8.31833
# Epoch [2/2], Step [4900/12942], Loss: 2.1089, Perplexity: 8.23933
# Epoch [2/2], Step [5000/12942], Loss: 1.9975, Perplexity: 7.37038
# Epoch [2/2], Step [5100/12942], Loss: 2.0190, Perplexity: 7.53069
# Epoch [2/2], Step [5200/12942], Loss: 2.2151, Perplexity: 9.16252
# Epoch [2/2], Step [5300/12942], Loss: 2.3728, Perplexity: 10.7274
# Epoch [2/2], Step [5400/12942], Loss: 2.9298, Perplexity: 18.7241
# Epoch [2/2], Step [5500/12942], Loss: 2.4222, Perplexity: 11.2702
# Epoch [2/2], Step [5600/12942], Loss: 1.8784, Perplexity: 6.54332
# Epoch [2/2], Step [5700/12942], Loss: 2.0224, Perplexity: 7.55631
# Epoch [2/2], Step [5800/12942], Loss: 2.1009, Perplexity: 8.17320
# Epoch [2/2], Step [5900/12942], Loss: 2.0504, Perplexity: 7.77087
# Epoch [2/2], Step [6000/12942], Loss: 2.2986, Perplexity: 9.96074
# Epoch [2/2], Step [6100/12942], Loss: 2.1637, Perplexity: 8.70323
# Epoch [2/2], Step [6200/12942], Loss: 2.1578, Perplexity: 8.65172
# Epoch [2/2], Step [6300/12942], Loss: 2.1713, Perplexity: 8.76954
# Epoch [2/2], Step [6400/12942], Loss: 2.3487, Perplexity: 10.4720
# Epoch [2/2], Step [6500/12942], Loss: 2.0502, Perplexity: 7.76935
# Epoch [2/2], Step [6600/12942], Loss: 2.3048, Perplexity: 10.0227
# Epoch [2/2], Step [6700/12942], Loss: 2.0064, Perplexity: 7.43683
# Epoch [2/2], Step [6800/12942], Loss: 2.4765, Perplexity: 11.9000
# Epoch [2/2], Step [6900/12942], Loss: 1.9560, Perplexity: 7.07120
# Epoch [2/2], Step [7000/12942], Loss: 2.2394, Perplexity: 9.38747
# Epoch [2/2], Step [7100/12942], Loss: 2.2100, Perplexity: 9.11553
# Epoch [2/2], Step [7200/12942], Loss: 2.5783, Perplexity: 13.1748
# Epoch [2/2], Step [7300/12942], Loss: 2.1471, Perplexity: 8.55978
# Epoch [2/2], Step [7400/12942], Loss: 2.1310, Perplexity: 8.42366
# Epoch [2/2], Step [7500/12942], Loss: 2.1937, Perplexity: 8.96818
# Epoch [2/2], Step [7600/12942], Loss: 2.0758, Perplexity: 7.97083
# Epoch [2/2], Step [7700/12942], Loss: 1.9360, Perplexity: 6.93133
# Epoch [2/2], Step [7800/12942], Loss: 2.1354, Perplexity: 8.46056
# Epoch [2/2], Step [7900/12942], Loss: 2.6083, Perplexity: 13.5760
# Epoch [2/2], Step [8000/12942], Loss: 1.9703, Perplexity: 7.17319
# Epoch [2/2], Step [8100/12942], Loss: 2.2334, Perplexity: 9.33154
# Epoch [2/2], Step [8200/12942], Loss: 2.5273, Perplexity: 12.5194
# Epoch [2/2], Step [8300/12942], Loss: 1.9883, Perplexity: 7.30283
# Epoch [2/2], Step [8400/12942], Loss: 2.2209, Perplexity: 9.21544
# Epoch [2/2], Step [8500/12942], Loss: 1.8448, Perplexity: 6.327172
# Epoch [2/2], Step [8600/12942], Loss: 2.3403, Perplexity: 10.3844
# Epoch [2/2], Step [8700/12942], Loss: 2.7539, Perplexity: 15.7044
# Epoch [2/2], Step [8800/12942], Loss: 2.0500, Perplexity: 7.76780
# Epoch [2/2], Step [8900/12942], Loss: 2.1130, Perplexity: 8.27265
# Epoch [2/2], Step [9000/12942], Loss: 2.1967, Perplexity: 8.99547
# Epoch [2/2], Step [9100/12942], Loss: 2.0200, Perplexity: 7.53867
# Epoch [2/2], Step [9200/12942], Loss: 2.1123, Perplexity: 8.26717
# Epoch [2/2], Step [9300/12942], Loss: 2.0726, Perplexity: 7.94551
# Epoch [2/2], Step [9400/12942], Loss: 2.1373, Perplexity: 8.47669
# Epoch [2/2], Step [9500/12942], Loss: 2.0795, Perplexity: 8.00063
# Epoch [2/2], Step [9600/12942], Loss: 2.5967, Perplexity: 13.4200
# Epoch [2/2], Step [9700/12942], Loss: 2.2108, Perplexity: 9.12282
# Epoch [2/2], Step [9800/12942], Loss: 1.7126, Perplexity: 5.54330
# Epoch [2/2], Step [9900/12942], Loss: 2.4434, Perplexity: 11.5127
# Epoch [2/2], Step [10000/12942], Loss: 2.1307, Perplexity: 8.4210
# Epoch [2/2], Step [10100/12942], Loss: 2.0228, Perplexity: 7.55911
# Epoch [2/2], Step [10200/12942], Loss: 2.3875, Perplexity: 10.8858
# Epoch [2/2], Step [10300/12942], Loss: 2.4966, Perplexity: 12.1417
# Epoch [2/2], Step [10400/12942], Loss: 1.9268, Perplexity: 6.86788
# Epoch [2/2], Step [10500/12942], Loss: 1.8824, Perplexity: 6.56934
# Epoch [2/2], Step [10600/12942], Loss: 2.0784, Perplexity: 7.99175
# Epoch [2/2], Step [10700/12942], Loss: 2.3165, Perplexity: 10.1400
# Epoch [2/2], Step [10800/12942], Loss: 2.3868, Perplexity: 10.8782
# Epoch [2/2], Step [10900/12942], Loss: 2.4519, Perplexity: 11.6101
# Epoch [2/2], Step [11000/12942], Loss: 2.1764, Perplexity: 8.81456
# Epoch [2/2], Step [11100/12942], Loss: 1.8568, Perplexity: 6.40314
# Epoch [2/2], Step [11200/12942], Loss: 1.9445, Perplexity: 6.98992
# Epoch [2/2], Step [11300/12942], Loss: 2.0978, Perplexity: 8.14864
# Epoch [2/2], Step [11400/12942], Loss: 2.1406, Perplexity: 8.50435
# Epoch [2/2], Step [11500/12942], Loss: 2.2129, Perplexity: 9.14250
# Epoch [2/2], Step [11600/12942], Loss: 2.1721, Perplexity: 8.77652
# Epoch [2/2], Step [11700/12942], Loss: 2.1202, Perplexity: 8.33262
# Epoch [2/2], Step [11800/12942], Loss: 1.9676, Perplexity: 7.15375
# Epoch [2/2], Step [11900/12942], Loss: 1.8815, Perplexity: 6.56322
# Epoch [2/2], Step [12000/12942], Loss: 2.1375, Perplexity: 8.47793
# Epoch [2/2], Step [12100/12942], Loss: 2.1213, Perplexity: 8.34207
# Epoch [2/2], Step [12200/12942], Loss: 2.0300, Perplexity: 7.61441
# Epoch [2/2], Step [12300/12942], Loss: 2.5099, Perplexity: 12.3040
# Epoch [2/2], Step [12400/12942], Loss: 2.0014, Perplexity: 7.39956
# Epoch [2/2], Step [12500/12942], Loss: 1.8858, Perplexity: 6.59171
# Epoch [2/2], Step [12600/12942], Loss: 1.7179, Perplexity: 5.57267
# Epoch [2/2], Step [12700/12942], Loss: 1.8175, Perplexity: 6.15661
# Epoch [2/2], Step [12800/12942], Loss: 2.0932, Perplexity: 8.11106
# Epoch [2/2], Step [12900/12942], Loss: 2.2797, Perplexity: 9.77403
# Epoch [2/2], Step [12942/12942], Loss: 2.0934, Perplexity: 8.11222

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
